# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\anagh\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Read the Dataset

# %%
df = pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
plt.xlabel('Exited')
plt.ylabel('Count')
df['Exited'].value_counts().plot.bar()
plt.show()

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df = pd.concat([df,pd.get_dummies(df['Geography'],prefix='Geo')],axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['Gender'])],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
#  14  Geo_France       10000 non-null  bool
#  15  Geo_Germany      10000 non-null  bool
#  16  Geo_Spain        10000 non-null  bool
#  17  Female           10000 non-null  bool
#  18  Male             10000 non-null  bool
# dtypes: bool(5), float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(columns=['RowNumber','CustomerId','Surname','Geography','Gender'],inplace=True)

# %%
#Distinguish the feature and target set and divide the data set into training and test sets.

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geo_France  Geo_Germany  \
# 0               1        101348.88       1        True        False
# 1               1        112542.58       0       False        False
# 2               0        113931.57       1        True        False
# 3               0         93826.63       0        True        False
# 4               1         79084.10       0       False        False
#
#    Geo_Spain  Female   Male
# 0      False    True  False
# 1       True    True  False
# 2      False    True  False
# 3      False    True  False
# 4       True    True  False

# %%
y = df['Exited'].values
x = df.loc[:,df.columns != 'Exited'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=20,test_size=0.25)

# %%
#Normalize the train and test data.

# %%
from sklearn.preprocessing import StandardScaler
std_x = StandardScaler()
x_train = std_x.fit_transform(x_train)
x_test = std_x.transform(x_test)

# %%
x_train.shape
# Out:
# (7500, 13)

# %%
#Initialize and build the model. Identify the points of improvement and implement the same.

# %%
#Tensorflow Model - Neural Network Classifier

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Conv1D,Flatten
from tensorflow.keras.models import Sequential, Model

# %%
model=Sequential()
model.add(Flatten(input_shape=(13,)))
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='BinaryCrossentropy')

# %%
model.fit(x_train,y_train,batch_size=64,validation_split=0.1,epochs=100)
# Out:
# Epoch 1/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.7684 - loss: 0.5280 - val_accuracy: 0.8253 - val_loss: 0.4150
# Epoch 2/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8106 - loss: 0.4292 - val_accuracy: 0.8360 - val_loss: 0.3937
# Epoch 3/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8216 - loss: 0.4098 - val_accuracy: 0.8440 - val_loss: 0.3751
# Epoch 4/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8396 - loss: 0.3915 - val_accuracy: 0.8573 - val_loss: 0.3596
# Epoch 5/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8396 - loss: 0.3860 - val_accuracy: 0.8627 - val_loss: 0.3471
# Epoch 6/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8450 - loss: 0.3714 - val_accuracy: 0.8693 - val_loss: 0.3341
# Epoch 7/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8514 - loss: 0.3537 - val_accuracy: 0.8733 - val_loss: 0.3318
# Epoch 8/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8532 - loss: 0.3548 - val_accuracy: 0.8747 - val_loss: 0.3306
# Epoch 9/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8578 - loss: 0.3432 - val_accuracy: 0.8773 - val_loss: 0.3251
# Epoch 10/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8548 - loss: 0.3559 - val_accuracy: 0.8773 - val_loss: 0.3224
# Epoch 11/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8549 - loss: 0.3459 - val_accuracy: 0.8747 - val_loss: 0.3218
# Epoch 12/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8567 - loss: 0.3424 - val_accuracy: 0.8800 - val_loss: 0.3198
# Epoch 13/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8559 - loss: 0.3493 - val_accuracy: 0.8760 - val_loss: 0.3159
# Epoch 14/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.
100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8638 - loss: 0.3220 - val_accuracy: 0.8827 - val_loss: 0.3112
# Epoch 78/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8624 - loss: 0.3296 - val_accuracy: 0.8800 - val_loss: 0.3151
# Epoch 79/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8642 - loss: 0.3222 - val_accuracy: 0.8773 - val_loss: 0.3197
# Epoch 80/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8709 - loss: 0.3093 - val_accuracy: 0.8840 - val_loss: 0.3141
# Epoch 81/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8692 - loss: 0.3190 - val_accuracy: 0.8827 - val_loss: 0.3196
# Epoch 82/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8686 - loss: 0.3112 - val_accuracy: 0.8760 - val_loss: 0.3156
# Epoch 83/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8795 - loss: 0.3086 - val_accuracy: 0.8787 - val_loss: 0.3165
# Epoch 84/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8625 - loss: 0.3164 - val_accuracy: 0.8773 - val_loss: 0.3195
# Epoch 85/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8659 - loss: 0.3191 - val_accuracy: 0.8867 - val_loss: 0.3111
# Epoch 86/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8795 - loss: 0.2997 - val_accuracy: 0.8813 - val_loss: 0.3153
# Epoch 87/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8703 - loss: 0.3153 - val_accuracy: 0.8840 - val_loss: 0.3173
# Epoch 88/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8649 - loss: 0.3202 - val_accuracy: 0.8800 - val_loss: 0.3156
# Epoch 89/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8705 - loss: 0.3135 - val_accuracy: 0.8787 - val_loss: 0.3191
# Epoch 90/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8694 - loss: 0.3132 - val_accuracy: 0.8813 - val_loss: 0.3127
# Epoch 91/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8742 - loss: 0.3056 - val_accuracy: 0.8787 - val_loss: 0.3130
# Epoch 92/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8663 - loss: 0.3085 - val_accuracy: 0.8773 - val_loss: 0.3193
# Epoch 93/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8745 - loss: 0.3013 - val_accuracy: 0.8827 - val_loss: 0.3215
# Epoch 94/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8778 - loss: 0.3014 - val_accuracy: 0.8760 - val_loss: 0.3226
# Epoch 95/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8680 - loss: 0.3120 - val_accuracy: 0.8867 - val_loss: 0.3140
# Epoch 96/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8718 - loss: 0.3077 - val_accuracy: 0.8680 - val_loss: 0.3191
# Epoch 97/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8837 - loss: 0.2947 - val_accuracy: 0.8827 - val_loss: 0.3196
# Epoch 98/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8667 - loss: 0.3141 - val_accuracy: 0.8787 - val_loss: 0.3145
# Epoch 99/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8748 - loss: 0.3027 - val_accuracy: 0.8827 - val_loss: 0.3183
# Epoch 100/100
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8749 - loss: 0.3034 - val_accuracy: 0.8800 - val_loss: 0.3139

# %%
pred = model.predict(x_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
y_pred = []
for val in pred:
    if val > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8628

# %%
cm = confusion_matrix(y_test,y_pred)
display = ConfusionMatrixDisplay(cm)
display.plot()

# %%
from sklearn.neural_network import MLPClassifier

# %%
nn_classifier = MLPClassifier(hidden_layer_sizes=(100),activation='logistic',max_iter=300,)
nn_classifier.fit(x_train,y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=100, max_iter=300)

# %%
y_pred2 = nn_classifier.predict(x_test)

# %%
accuracy_score(y_pred=y_pred2,y_true=y_test)
# Out:
# 0.8636

# %%
nn_classifier.score(x_test,y_test)
# Out:
# 0.8636
